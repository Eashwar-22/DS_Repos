# %%
import pandas as pd
import numpy as np
import eda_class
# %matplotlib inline

# %%
df=pd.read_csv('train.csv')
# df.head()

# %%
a=eda_class.EDA_Summary(df,
                        temporal_features=['YearBuilt', 'YearRemodAdd','GarageYrBlt', 'YrSold'],
                        id_features=['Id'])

# %%
a.get_missing_features(df)

# %%
a.missing_value_dependency(df,'SalePrice')

# %%
# a.get_numerical_features(True)

# %%
a.feature_type(df,'Id')

# %%
# temp=df.groupby(['YearBuilt','YrSold']).agg({'SalePrice':'median'}).reset_index()
# a.plot_(temp.iloc[:10],kind='line',x='YrSold',y='SalePrice',figsize=(20,14),hue='YearBuilt')

# %%
a.discrete_target_plot('SalePrice')

# %%
# a.continuous_hist_plot()

# %%
a.plot_(df=df,x='SalePrice',hue='SaleType',multiple='stack',kind='hist',figsize=(10,10))

# %%
df[(df['SalePrice']>400000) & (df['SaleType']=='WD')]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 161    162          60       RL        110.0    13688   Pave   NaN      IR1
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 231    232          60       RL        174.0    15138   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 496    497          20       RL          NaN    12692   Pave   NaN      IR1
# 661    662          60       RL         52.0    46589   Pave   NaN      IR2
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1353  1354          50       RL         56.0    14720   Pave   NaN      IR1
# ...
